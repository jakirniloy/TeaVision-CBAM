# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        break

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tea-leaf-health-dataset/Tea leaf Dataset/Diseased Leaf/IMG20230816192835.jpg
# /kaggle/input/tea-leaf-health-dataset/Tea leaf Dataset/Healthy Leaf/IMG20230816190644.jpg

# %% [markdown]
# # =========================
# # Task 1: EDA + Aug Probe
# # =========================

# %%
import os, glob, random, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from collections import Counter

import cv2

# %%
DATA_DIR = "/kaggle/input/tea-leaf-health-dataset/Tea leaf Dataset"  # change if needed
CLASSES = ["Healthy Leaf", "Diseased Leaf"]

# %%
filepaths, labels = [], []
for i, cls in enumerate(CLASSES):
    paths = glob.glob(os.path.join(DATA_DIR, cls, "*"))
    paths = [p for p in paths if p.lower().endswith((".jpg",".jpeg",".png",".bmp",".webp"))]
    filepaths.extend(paths)
    labels.extend([i]*len(paths))

df = pd.DataFrame({"filepath": filepaths, "label": labels})
df["class"] = df["label"].map({0: CLASSES[0], 1: CLASSES[1]})

print(df.head())
print("\nTotal images:", len(df))

# --------- Class balance ----------
counts = df["class"].value_counts()
print("\nClass distribution:\n", counts)

plt.figure()
plt.bar(counts.index, counts.values)
plt.title("Class Distribution")
plt.xticks(rotation=0)
plt.show()
# Out:
#                                             filepath  label         class
# 0  /kaggle/input/tea-leaf-health-dataset/Tea leaf...      0  Healthy Leaf
# 1  /kaggle/input/tea-leaf-health-dataset/Tea leaf...      0  Healthy Leaf
# 2  /kaggle/input/tea-leaf-health-dataset/Tea leaf...      0  Healthy Leaf
# 3  /kaggle/input/tea-leaf-health-dataset/Tea leaf...      0  Healthy Leaf
# 4  /kaggle/input/tea-leaf-health-dataset/Tea leaf...      0  Healthy Leaf
#
# Total images: 747
#
# Class distribution:
#  class
# Diseased Leaf    395
# Healthy Leaf     352
# Name: count, dtype: int64

# %%
def show_samples(df, n=8):
    sample = df.sample(n=min(n, len(df)), random_state=42)
    cols = 4
    rows = int(np.ceil(len(sample)/cols))
    plt.figure(figsize=(12, 3*rows))
    for idx, (_, r) in enumerate(sample.iterrows()):
        img = Image.open(r["filepath"]).convert("RGB")
        plt.subplot(rows, cols, idx+1)
        plt.imshow(img)
        plt.title(r["class"])
        plt.axis("off")
    plt.tight_layout()
    plt.show()

show_samples(df, n=12)

# %%
def get_img_info(path):
    img = Image.open(path)
    w, h = img.size
    return w, h, w/h

ws, hs, ars = [], [], []
for p in df["filepath"].sample(min(500, len(df)), random_state=7):  # sample for speed
    w, h, ar = get_img_info(p)
    ws.append(w); hs.append(h); ars.append(ar)

info_df = pd.DataFrame({"width": ws, "height": hs, "aspect_ratio": ars})
print(info_df.describe())

plt.figure()
plt.hist(info_df["width"], bins=30)
plt.title("Width Distribution (sampled)")
plt.show()

plt.figure()
plt.hist(info_df["height"], bins=30)
plt.title("Height Distribution (sampled)")
plt.show()

plt.figure()
plt.hist(info_df["aspect_ratio"], bins=30)
plt.title("Aspect Ratio Distribution (sampled)")
plt.show()
# Out:
#              width     height  aspect_ratio
# count   500.000000   500.0000    500.000000
# mean   3982.834000  3783.2420      1.097666
# std     960.915688   969.8504      0.286516
# min     960.000000   960.0000      0.750000
# 25%    3468.000000  3468.0000      0.750000
# 50%    4624.000000  3468.0000      1.333333
# 75%    4624.000000  4624.0000      1.333333
# max    9248.000000  9248.0000      1.333333

# %%
def rgb_hist(img_np):
    # img_np uint8 RGB
    hists = []
    for c in range(3):
        hist, _ = np.histogram(img_np[:,:,c].ravel(), bins=256, range=(0,255))
        hists.append(hist)
    return hists

sample_paths = df["filepath"].sample(min(30, len(df)), random_state=13).tolist()
acc_hist = [np.zeros(256), np.zeros(256), np.zeros(256)]

for p in sample_paths:
    img = np.array(Image.open(p).convert("RGB"))
    hists = rgb_hist(img)
    for c in range(3):
        acc_hist[c] += hists[c]

plt.figure()
plt.plot(acc_hist[0], label="R")
plt.plot(acc_hist[1], label="G")
plt.plot(acc_hist[2], label="B")
plt.title("Aggregated RGB Histogram (sampled images)")
plt.legend()
plt.show()

# %% [markdown]
# # ===========================================================================================
# # Task 2: Pre-trained Baselines (ResNet, VGG, EfficientNet) + Metrics + K-fold + Paired t-test
# # ============================================================================================

# %%
import os, time
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score, roc_curve
)
from scipy.stats import ttest_rel

from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import EarlyStopping

SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 50            
LR = 1e-4
N_SPLITS = 5
# Out:
# 2026-02-22 19:14:32.156193: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771787672.329571      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771787672.379338      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771787672.809824      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771787672.809863      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771787672.809866      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771787672.809868      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
X = df["filepath"].values
y = df["label"].values

# %%
AUTOTUNE = tf.data.AUTOTUNE

def decode_and_resize(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    return img, tf.cast(label, tf.int32)

train_aug = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.15),
])

def make_ds(paths, labels, training=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    ds = ds.shuffle(len(paths), seed=SEED, reshuffle_each_iteration=True) if training else ds
    ds = ds.map(decode_and_resize, num_parallel_calls=AUTOTUNE)
    if training:
        ds = ds.map(lambda x, y: (train_aug(x, training=True), y), num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds
# Out:
# I0000 00:00:1771787685.326987      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix,
    roc_auc_score, roc_curve, auc
)

# %% [markdown]
# # =============================
# # Model Builder
# # =============================

# %%
def build_model(backbone_name):

    if backbone_name == "ResNet50":
        base = tf.keras.applications.ResNet50(
            include_top=False, weights="imagenet",
            input_shape=(IMG_SIZE, IMG_SIZE, 3)
        )
        preprocess = tf.keras.applications.resnet.preprocess_input

    elif backbone_name == "VGG16":
        base = tf.keras.applications.VGG16(
            include_top=False, weights="imagenet",
            input_shape=(IMG_SIZE, IMG_SIZE, 3)
        )
        preprocess = tf.keras.applications.vgg16.preprocess_input

    elif backbone_name == "EfficientNetB0":
        base = tf.keras.applications.EfficientNetB0(
            include_top=False, weights="imagenet",
            input_shape=(IMG_SIZE, IMG_SIZE, 3)
        )
        preprocess = tf.keras.applications.efficientnet.preprocess_input

    else:
        raise ValueError("Unknown backbone")

    base.trainable = False  # freeze backbone

    inp = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = preprocess(inp)
    x = base(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(1, activation="sigmoid")(x)

    model = Model(inp, out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %% [markdown]
# # =============================
# # Evaluation Metrics
# # =============================

# %%
def eval_metrics(y_true, y_prob):

    y_pred = (y_prob >= 0.5).astype(int)

    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    cm = confusion_matrix(y_true, y_pred)

    per_class_acc = (
        cm.diagonal() / cm.sum(axis=1)
    ).tolist() if cm.sum() > 0 else [0, 0]

    try:
        auc_score = roc_auc_score(y_true, y_prob)
    except:
        auc_score = np.nan

    return {
        "accuracy": acc,
        "precision": prec,
        "recall": rec,
        "f1": f1,
        "auc": auc_score,
        "cm": cm,
        "per_class_acc": per_class_acc
    }

# %% [markdown]
# # =============================
# # Training Setup
# # =============================

# %%
backbones = ["ResNet50", "VGG16", "EfficientNetB0"]

histories = {b: [] for b in backbones}
roc_data = {b: [] for b in backbones}
all_results = []

skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)

# =============================
# Cross Validation Loop
# =============================
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), 1):

    print(f"\n========== Fold {fold}/{N_SPLITS} ==========")

    X_train, y_train = X[train_idx], y[train_idx]
    X_test, y_test = X[test_idx], y[test_idx]

    train_ds = make_ds(X_train, y_train, training=True)
    test_ds = make_ds(X_test, y_test, training=False)

    for backbone in backbones:

        print(f"\n--- Training {backbone} ---")

        model = build_model(backbone)

        t0 = time.time()

        history = model.fit(
            train_ds,
            epochs=EPOCHS,
            validation_data=test_ds,
            verbose=1,
            callbacks=[EarlyStopping(patience=2, restore_best_weights=True)]
        )

        train_time = time.time() - t0

        # Prediction
        t1 = time.time()
        y_prob = model.predict(test_ds, verbose=0).ravel()
        infer_time = time.time() - t1

        metrics = eval_metrics(y_test, y_prob)

        histories[backbone].append(history.history)
        roc_data[backbone].append((y_test, y_prob))

        all_results.append({
            "fold": fold,
            "model": backbone,
            "accuracy": metrics["accuracy"],
            "precision": metrics["precision"],
            "recall": metrics["recall"],
            "f1": metrics["f1"],
            "auc": metrics["auc"],
            "healthy_acc": metrics["per_class_acc"][0],
            "diseased_acc": metrics["per_class_acc"][1],
            "train_time_sec": train_time,
            "infer_time_sec": infer_time
        })

        print("Confusion Matrix:\n", metrics["cm"])
        print(f"Acc={metrics['accuracy']:.4f}, "
              f"P={metrics['precision']:.4f}, "
              f"R={metrics['recall']:.4f}, "
              f"F1={metrics['f1']:.4f}, "
              f"AUC={metrics['auc']:.4f}")
# Out:
# ========== Fold 1/5 ==========
#
# --- Training ResNet50 ---
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771787699.580645      67 service.cc:152] XLA service 0x7f6e0004ba70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771787699.580685      67 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1771787704.472588      67 cuda_dnn.cc:529] Loaded cuDNN version 91002
#  3/19 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5799 - loss: 0.7673
# I0000 00:00:1771787710.447441      67 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 85s 4s/step - accuracy: 0.4999 - loss: 0.8498 - val_accuracy: 0.4733 - val_loss: 0.7781
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.4966 - loss: 0.8583 - val_accuracy: 0.4733 - val_loss: 0.7270
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.4770 - loss: 0.7692 - val_accuracy: 0.4733 - val_loss: 0.7033
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5225 - loss: 0.7412 - val_accuracy: 0.5200 - val_loss: 0.6907
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 67s 4s/step - accuracy: 0.5000 - loss: 0.7318 - val_accuracy: 0.5267 - val_loss: 0.6859
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5050 - loss: 0.7523 - val_accuracy: 0.5267 - val_loss: 0.6852
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 67s 4s/step - accuracy: 0.5376 - loss: 0.7304 - val_accuracy: 0.5267 - val_loss: 0.6846
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5291 - loss: 0.7298 - val_accuracy: 0.5267 - val_loss: 0.6842
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.5381 - loss: 0.7180 - val_accuracy: 0.5267 - val_loss: 0.6843
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 67s 4s/step - accuracy: 0.4846 - loss: 0.7306 - val_accuracy: 0.5267 - val_loss: 0.6840
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 100s 4s/step - accuracy: 0.4787 - loss: 0.7218 - val_accuracy: 0.4698 - val_loss: 0.7020
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.4891 - loss: 0.7036 - val_accuracy: 0.5302 - val_loss: 0.6926
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5142 - loss: 0.6946 - val_accuracy: 0.5302 - val_loss: 0.6914
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.4868 - loss: 0.6945 - val_accuracy: 0.5302 - val_loss: 0.6912
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5426 - loss: 0.6907 - val_accuracy: 0.5302 - val_loss: 0.6912
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5575 - loss: 0.6882 - val_accuracy: 0.5302 - val_loss: 0.6912
# Confusion Matrix:
#  [[ 0 70]
#  [ 0 79]]
# Acc=0.5302, P=0.5302, R=1.0000, F1=0.6930, AUC=0.8189

# %% [markdown]
# # =============================
# # Summary Table
# # =============================

# %%
results_df = pd.DataFrame(all_results)

print("\n===== Mean Across Folds =====")
summary = results_df.groupby("model").mean().sort_values("accuracy", ascending=False)
print(summary)
# Out:
# ===== Mean Across Folds =====
#                 fold  accuracy  precision  recall        f1       auc  \
# model
# EfficientNetB0   3.0  0.528787   0.528787     1.0  0.691772  0.479701
# ResNet50         3.0  0.528787   0.528787     1.0  0.691772  0.899887
# VGG16            3.0  0.528787   0.528787     1.0  0.691772  0.565663
#
#                 healthy_acc  diseased_acc  train_time_sec  infer_time_sec
# model
# EfficientNetB0          0.0           1.0      458.413958       22.977318
# ResNet50                0.0           1.0     3404.052329       18.197826
# VGG16                   0.0           1.0     1003.442969       13.672371

# %% [markdown]
# # =============================
# # Plot Accuracy & Loss Curves
# # =============================

# %%
def plot_accuracy_loss(histories, metric):

    plt.figure(figsize=(8,6))

    for backbone in histories.keys():

        min_epochs = min(len(h[metric]) for h in histories[backbone])
        mean_train = []
        mean_val = []

        for epoch in range(min_epochs):
            train_vals = [h[metric][epoch] for h in histories[backbone]]
            val_vals = [h[f"val_{metric}"][epoch] for h in histories[backbone]]

            mean_train.append(np.mean(train_vals))
            mean_val.append(np.mean(val_vals))

        plt.plot(mean_train, label=f"{backbone} Train")
        plt.plot(mean_val, linestyle="--", label=f"{backbone} Val")

    plt.title(f"{metric.capitalize()} Curve")
    plt.xlabel("Epoch")
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.grid(True)
    plt.show()


plot_accuracy_loss(histories, "accuracy")
plot_accuracy_loss(histories, "loss")

# %% [markdown]
# # =============================
# # Plot ROC Curve
# # =============================

# %%
def plot_roc(roc_data):

    plt.figure(figsize=(8,6))

    for backbone in roc_data.keys():

        all_fpr = np.linspace(0,1,100)
        tprs = []
        aucs = []

        for y_true, y_prob in roc_data[backbone]:
            fpr, tpr, _ = roc_curve(y_true, y_prob)
            roc_auc = auc(fpr, tpr)

            aucs.append(roc_auc)
            tpr_interp = np.interp(all_fpr, fpr, tpr)
            tpr_interp[0] = 0.0
            tprs.append(tpr_interp)

        mean_tpr = np.mean(tprs, axis=0)
        mean_auc = np.mean(aucs)

        plt.plot(all_fpr, mean_tpr,
                 label=f"{backbone} (AUC={mean_auc:.3f})")

    plt.plot([0,1],[0,1],'k--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("Mean ROC Curve Across Folds")
    plt.legend()
    plt.grid(True)
    plt.show()


plot_roc(roc_data)
